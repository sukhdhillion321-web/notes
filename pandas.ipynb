# %% [markdown]
# <a href="https://colab.research.google.com/github/sukhdhillion321-web/notes/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data =pd.Series([1,2,3,4,5])
data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data=pd.Series([1,2,3,4,5],dtype=float)
data
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# dtype: float64

# %%
data.dtype
# Out:
# dtype('int64')

# %%
data.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
data.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(data.name)
# Out:
# None

# %%
data.name="sukh"
data
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# Name: sukh, dtype: float64

# %%
data=pd.Series([1,2,3,4,5],dtype=int)
data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#indexing
data[0]
# Out:
# np.int64(1)

# %%
data[0:2]
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
data[::2]
# Out:
# 0    1
# 2    3
# 4    5
# dtype: int64

# %%
#iloc<- uses location(loacation based indexing)
data.iloc[3]
# Out:
# np.int64(4)

# %%
data.iloc[[1,3,4]]
# Out:
# 1    2
# 3    4
# 4    5
# dtype: int64

# %%
index=["workout","excercise","eat","sleep","walk"]

# %%
data.index=index
data
# Out:
# workout      1
# excercise    2
# eat          3
# sleep        4
# walk         5
# dtype: int64

# %%
data["eat"]
# Out:
# np.int64(3)

# %%
#loc <- label based indexing
#stop value is also included
data.loc["eat"]
# Out:
# np.int64(3)

# %%
data.loc["sleep"]
# Out:
# np.int64(4)

# %%
details={
    "name":"sukh",
    "age":20,
    "job":"engineer"
}

# %%
my_series=pd.Series(details,name="details")
my_series
# Out:
# name        sukh
# age           20
# job     engineer
# Name: details, dtype: object

# %%
h={
    "name":["sukh","raj","gur","man"],
    "roll_no":["02","03","04","05"],
    "hobies":["dance","singing","reading","writing"],
    "favourite_colors":["red","black","yellow","orange"]
}

# %%
df=pd.DataFrame(h)
df
# Out:
#    name roll_no   hobies favourite_colors
# 0  sukh      02    dance              red
# 1   raj      03  singing            black
# 2   gur      04  reading           yellow
# 3   man      05  writing           orange

# %%
df.head(2)
# Out:
#    name roll_no   hobies favourite_colors
# 0  sukh      02    dance              red
# 1   raj      03  singing            black

# %%
df.tail(2)
# Out:
#   name roll_no   hobies favourite_colors
# 2  gur      04  reading           yellow
# 3  man      05  writing           orange

# %%
df.iloc[1:3]
# Out:
#   name roll_no   hobies favourite_colors
# 1  raj      03  singing            black
# 2  gur      04  reading           yellow

# %%
df.loc[1:3,["roll_no","name"]]
# Out:
#   roll_no name
# 1      03  raj
# 2      04  gur
# 3      05  man

# %%
df[["name","roll_no"]]
# Out:
#    name roll_no
# 0  sukh      02
# 1   raj      03
# 2   gur      04
# 3   man      05

# %%
df.drop("hobies",axis=1)
# Out:
#    name roll_no favourite_colors
# 0  sukh      02              red
# 1   raj      03            black
# 2   gur      04           yellow
# 3   man      05           orange

# %%
df
# Out:
#    name roll_no   hobies favourite_colors
# 0  sukh      02    dance              red
# 1   raj      03  singing            black
# 2   gur      04  reading           yellow
# 3   man      05  writing           orange

# %%
df.drop("hobies",axis=1,inplace=True)

# %%
df
# Out:
#    name roll_no favourite_colors
# 0  sukh      02              red
# 1   raj      03            black
# 2   gur      04           yellow
# 3   man      05           orange

# %%
df.shape
# Out:
# (4, 3)

# %%
df.dtypes
# Out:
# name                object
# roll_no             object
# favourite_colors    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              4 non-null      object
#  1   roll_no           4 non-null      object
#  2   favourite_colors  4 non-null      object
# dtypes: object(3)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#         name roll_no favourite_colors
# count      4       4                4
# unique     4       4                4
# top     sukh      02              red
# freq       1       1                1

# %%
df.rename(columns={"favourite_colors":"colors"},inplace=True)
df
# Out:
#    name roll_no  colors
# 0  sukh      02     red
# 1   raj      03   black
# 2   gur      04  yellow
# 3   man      05  orange

# %%
df["colors"].value_counts()
# Out:
# colors
# red       1
# black     1
# yellow    1
# orange    1
# Name: count, dtype: int64
