# %% [markdown]
# <a href="https://colab.research.google.com/github/sukhdhillion321-web/notes/blob/main/variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#printing statements and variables

# %%
print("sukhjit kaur")
print("age=19")
print("b.tech cse")
print("sant baba bhag singh univercity")
# Out:
# sukhjit kaur
# age=19
# b.tech cse
# sant baba bhag singh univercity

# %%
print("sukhjit kaur","age=19","b.tech cse","sant baba bhag singh university",sep="-")
# Out:
# sukhjit kaur-age=19-b.tech cse-sant baba bhag singh university

# %%
print("sukhjit","kaur",end=" ")
# Out:
# sukhjit kaur

# %%
print("sukhjit",end="")
print("kaur")
# Out:
# sukhjitkaur

# %%
print("sukhjit",sep="-")
print("kaur")
# Out:
# sukhjit
# kaur

# %%
name="sukh"
age=20
print(f"my name is{name} and my age is{age}")
# Out:
# my name issukh and my age is20

# %%
fruits="apple","banana","mango"
print(fruits)
# Out:
# ('apple', 'banana', 'mango')

# %%
colors="red","yellow","green"
print(colors)
# Out:
# ('red', 'yellow', 'green')
